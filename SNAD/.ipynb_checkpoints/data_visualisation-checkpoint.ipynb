# %%
import sys 

sys.path.insert(1, '/media3/etienne/workdir/spark_AGN/Visualise')
from visualise_tools import *

sys.path.insert(1, '/media3/etienne/workdir/spark_AGN/Build_classifier')
from classifier_tools import *

# %%
features = pd.read_parquet('features.parquet')
features
# Out:
#                a            t0         tT       tfall        trise  \
# 0     194.165641  61112.031903  18.222850   28.860685    -2.498771
# 1     230.424701  61236.655145  23.710148   32.296483    -3.176959
# 2     150.437596  61118.723326   3.451203   26.920482    -4.503356
# 3    1537.744529  61164.852986  26.424311   36.405688 -1160.510647
# 4     138.825578  60941.646151   4.074005   25.614618    -4.388356
# ..           ...           ...        ...         ...          ...
# 650   121.818157  60726.094650   5.384423   19.476485    -5.477632
# 651    42.983592  60735.045515 -22.188097   99.345735    -1.095270
# 652  1458.002941  60660.278298  11.203965   24.608872    -2.060037
# 653    91.565857  60533.731562  29.333282   88.612847    -4.132303
# 654    88.655589  61357.637846  -1.097102  248.122738    -3.651339
#
#              Tmin          Tmax       ksig
# 0     3594.946024   7496.993135   2.968295
# 1     3414.764770   6760.790161   7.833934
# 2     4001.071229   6801.840056   0.720162
# 3     4102.678151   1429.818940  12.057381
# 4     5178.747200   7322.232278   0.122731
# ..            ...           ...        ...
# 650   3249.296745   5292.841366   1.513793
# 651   2170.450492  51276.489186  14.473052
# 652   9662.969594   5897.960647  -0.000582
# 653   2222.291345   5370.629540  11.752418
# 654  10386.087995   1083.265852  17.590606
#
# [655 rows x 8 columns]

# %%
param_names = ['a', 't0', 'tT', 'tfall', 'trise', 'Tmin', 'dT', 'ksig']

# %%
for i in features.keys():
    plt.figure()
    plt.title(i)
    
    zoom = zoom_in(features, 0.95, param_names)
    zoom_features = features[zoom]
    
    nbins = 40
    
    plt.hist(zoom_features[i], bins = nbins, alpha=0.7, density=True);

features.keys()
# Out:
# Index(['a', 't0', 'tT', 'tfall', 'trise', 'Tmin', 'Tmax', 'ksig'], dtype='object')

# %%
parameters = param_names
parameters_to_zoom = param_names

zoom = 0.95
mask_zoom = zoom_in(features, zoom, parameters_to_zoom)

sns.set_theme(style="ticks")

sns_plot = sns.pairplot(features[mask_zoom])

# %%
parameters = param_names
parameters_to_zoom = param_names

zoom = 1
mask_zoom = zoom_in(features, zoom, parameters_to_zoom)

sns.set_theme(style="ticks")

sns_plot = sns.pairplot(features[mask_zoom])
